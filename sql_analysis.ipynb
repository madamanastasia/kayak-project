# %%
import sqlite3

conn = sqlite3.connect("kayak.db")

# %%
cursor = conn.cursor()

cursor.executescript("""
CREATE TABLE IF NOT EXISTS cities (
    city_id INTEGER PRIMARY KEY,
    city_name TEXT,
    latitude REAL,
    longitude REAL
);

CREATE TABLE IF NOT EXISTS weather_daily (
    weather_id INTEGER,
    city_id INTEGER,
    forecast_date DATE,
    temp_mean_c REAL,
    temp_min_c REAL,
    temp_max_c REAL,
    pop_mean REAL,
    rain_mm_sum REAL,
    FOREIGN KEY (city_id) REFERENCES cities(city_id)
);

CREATE TABLE IF NOT EXISTS hotels (
    hotel_id INTEGER PRIMARY KEY,
    city_id INTEGER,
    hotel_name TEXT,
    url TEXT,
    latitude REAL,
    longitude REAL,
    rating REAL,
    description TEXT,
    FOREIGN KEY (city_id) REFERENCES cities(city_id)
);
""")

conn.commit()

# %%
import pandas as pd

# %%
query = """
SELECT
    c.city_name,
    c.latitude,
    c.longitude,
    AVG(w.temp_mean_c) AS avg_temperature,
    AVG(w.pop_mean) AS mean_pop
FROM cities c
JOIN weather_daily w
    ON c.city_id = w.city_id
GROUP BY c.city_name, c.latitude, c.longitude;
"""

df_sql = pd.read_sql(query, conn)
df_sql
# Out:
#                        city_name   latitude  longitude  avg_temperature  \
# 0                  Aigues Mortes  43.566152   4.191540        16.658236
# 1                Aix en Provence  43.529842   5.447474        17.334917
# 2                         Amiens  49.894171   2.295695        12.060292
# 3                         Annecy  45.899235   6.128885        10.527569
# 4                         Ariege  42.945537   1.406554        13.122486
# 5                        Avignon  43.949249   4.805901        15.414681
# 6                         Bayeux  49.276462  -0.702474        12.503000
# 7                        Bayonne  43.494514  -1.473666        16.684833
# 8                       Besancon  47.238022   6.024362        10.013250
# 9                       Biarritz  43.483252  -1.559278        17.002458
# 10            Bormes les Mimosas  43.150697   6.341928        16.227069
# 11                   Carcassonne  43.213036   2.349107        17.150194
# 12                        Cassis  43.214036   5.539632        17.584278
# 13  Chateau du Haut Koenigsbourg  48.249411   7.344320         8.191125
# 14                     Collioure  42.525050   3.083155        17.329778
# 15                        Colmar  48.077752   7.357964        10.866708
# 16                         Dijon  47.321581   5.041470        10.291042
# 17                     Eguisheim  48.044797   7.307962        10.628792
# 18              Gorges du Verdon  43.749656   6.328562        11.128403
# 19                      Grenoble  45.187560   5.735782        14.104847
# 20                   La Rochelle  46.159732  -1.151595        15.099833
# 21                      Le Havre  49.493898   0.107973        13.662486
# 22                         Lille  50.636565   3.063528        12.541583
# 23                          Lyon  45.757814   4.832011        12.564625
# 24                     Marseille  43.296174   5.369953        18.681792
# 25             Mont Saint Michel  48.635954  -1.511460        12.656083
# 26                     Montauban  44.017584   1.354999        16.437042
# 27                         Nimes  43.837425   4.360069        16.381722
# 28                         Paris  48.853495   2.348391        13.819486
# 29                         Rouen  49.440459   1.093966        12.316833
# 30      Saintes Maries de la mer  43.451592   4.427720        16.724764
# 31                       St Malo  48.649518  -2.026041        13.843861
# 32                    Strasbourg  48.584614   7.750713        11.293139
# 33                      Toulouse  43.604464   1.444243        17.544708
# 34                          Uzes  44.012128   4.419672        15.015528
#
#     mean_pop
# 0   0.000000
# 1   0.029375
# 2   0.000000
# 3   0.000000
# 4   0.179444
# 5   0.000000
# 6   0.019444
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.056458
# 11  0.003333
# 12  0.059306
# 13  0.000000
# 14  0.049306
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.129653
# 19  0.000000
# 20  0.000000
# 21  0.004167
# 22  0.027778
# 23  0.000000
# 24  0.064903
# 25  0.000000
# 26  0.000000
# 27  0.000000
# 28  0.000000
# 29  0.000000
# 30  0.000000
# 31  0.000000
# 32  0.000000
# 33  0.000000
# 34  0.000000

# %%
import plotly.express as px

fig = px.scatter_mapbox(
    df_sql,
    lat="latitude",
    lon="longitude",
    color="avg_temperature",
    size="avg_temperature",
    hover_name="city_name",
    color_continuous_scale="Bluered",
    zoom=4.5,
    height=650,
    title="Top destinations selon les conditions météorologiques"
)

fig.update_layout(mapbox_style="carto-positron")
fig.show()

# %%
query_top5 = """
SELECT
    c.city_name,
    c.latitude,
    c.longitude,
    AVG(w.temp_mean_c) AS avg_temperature,
    AVG(w.pop_mean) AS mean_pop
FROM cities c
JOIN weather_daily w ON c.city_id = w.city_id
GROUP BY c.city_name, c.latitude, c.longitude
HAVING AVG(w.temp_mean_c) BETWEEN 17 AND 22
ORDER BY AVG(w.pop_mean) ASC,
         AVG(w.temp_mean_c) DESC,
         c.city_name ASC
LIMIT 5;
"""
df_top5 = pd.read_sql(query_top5, conn)
df_top5
# Out:
#          city_name   latitude  longitude  avg_temperature  mean_pop
# 0         Toulouse  43.604464   1.444243        17.544708  0.000000
# 1         Biarritz  43.483252  -1.559278        17.002458  0.000000
# 2      Carcassonne  43.213036   2.349107        17.150194  0.003333
# 3  Aix en Provence  43.529842   5.447474        17.334917  0.029375
# 4        Collioure  42.525050   3.083155        17.329778  0.049306

# %%
import plotly.express as px

fig = px.scatter_mapbox(
    df_top5,
    lat="latitude",
    lon="longitude",
    hover_name="city_name",
    hover_data={
        "avg_temperature": ":.1f",
        "mean_pop": ":.3f",
        "latitude": False,
        "longitude": False,
    },
    color="city_name",        
    zoom=4,
    height=650,
    title="Top 5 villes sélectionnées selon la météo"
)

fig.update_layout(
    mapbox_style="open-street-map",
    margin=dict(l=10, r=10, t=60, b=10),
    legend_title_text="Ville"
)
fig.update_traces(marker=dict(size=14))

fig.show()

# %%
query_hotels = """
SELECT
    h.hotel_id,
    h.hotel_name,
    h.latitude,
    h.longitude,
    h.rating,
    h.url,
    c.city_name
FROM hotels h
JOIN cities c
    ON h.city_id = c.city_id
WHERE h.latitude IS NOT NULL
  AND h.longitude IS NOT NULL;
"""
df_hotels = pd.read_sql(query_hotels, conn)
df_hotels.head()
# Out:
#    hotel_id                                         hotel_name   latitude  \
# 0         1  CABADOL - Appartement Aix centre historique - ...  43.525963
# 1         2                             Chambre style balinais  43.528428
# 2         3  Château de Saint-Girons - Luxury Guest House i...  43.498920
# 3         4                             Domaine de Saint Clair  43.499156
# 4         5   Duplex indépendant avec clim et parking St Donat  43.560699
#
#    longitude  rating                                                url  \
# 0   5.451841     9.4  https://www.booking.com/hotel/fr/appartement-a...
# 1   5.452377     9.4  https://www.booking.com/hotel/fr/chambre-style...
# 2   5.382602     9.8  https://www.booking.com/hotel/fr/chateau-de-sa...
# 3   5.432056     9.7  https://www.booking.com/hotel/fr/domaine-de-sa...
# 4   5.451552     9.8  https://www.booking.com/hotel/fr/independent-a...
#
#          city_name
# 0  Aix en Provence
# 1  Aix en Provence
# 2  Aix en Provence
# 3  Aix en Provence
# 4  Aix en Provence

# %%
df_top = df_hotels.sort_values("rating", ascending=False).head(200)

fig = px.scatter_mapbox(
    df_top,
    lat="latitude",
    lon="longitude",
    color="rating",
    hover_name="hotel_name",
    hover_data={"city_name": True, "rating": True, "url": True},
    zoom=4.5,
    height=650,
    title="Top 20 Hôtels par note"
)
fig.update_layout(mapbox_style="carto-positron")
fig.show()
